# %%
from damavand.damavand.datasets.downloaders import ZipDatasetDownloader
link = "https://data.mendeley.com/public-api/zip/cbv7jyx4p9/download/3"
base_dir = "/nfs/home/amiber/ml_for_pdm_course_project/"


downloader = ZipDatasetDownloader(url=link)
downloader.download_extract(f"{base_dir}hust.zip", f"{base_dir}hust/")

# %%
import os
os.listdir(
    "/nfs/home/amiber/ml_for_pdm_course_project/hust/HUST bearing a practical dataset for ball bearing fault diagnosis/HUST bearing dataset/"
)
# Out:
# ['B602.mat',
#  'B604.mat',
#  'B800.mat',
#  'B504.mat',
#  'B704.mat',
#  'B502.mat',
#  'B702.mat',
#  'B500.mat',
#  'B700.mat',
#  'B600.mat',
#  'B804.mat',
#  'B802.mat',
#  'I400.mat',
#  'I402.mat',
#  'I404.mat',
#  'I504.mat',
#  'I500.mat',
#  'I502.mat',
#  'I600.mat',
#  'I602.mat',
#  'I700.mat',
#  'I702.mat',
#  'I800.mat',
#  'I802.mat',
#  'IB500.mat',
#  'I804.mat',
#  'I704.mat',
#  'IB502.mat',
#  'IB504.mat',
#  'IB602.mat',
#  'IB600.mat',
#  'IB604.mat',
#  'IB700.mat',
#  'IB802.mat',
#  'IB800.mat',
#  'IB804.mat',
#  'IB702.mat',
#  'IB704.mat',
#  'IO400.mat',
#  'IO402.mat',
#  'IO404.mat',
#  'IO500.mat',
#  'IO502.mat',
#  'IO504.mat',
#  'IO702.mat',
#  'IO704.mat',
#  'IO600.mat',
#  'IO604.mat',
#  'IO602.mat',
#  'IO700.mat',
#  'IO800.mat',
#  'IO804.mat',
#  'IO802.mat',
#  'N400.mat',
#  'N402.mat',
#  'N500.mat',
#  'N404.mat',
#  'N502.mat',
#  'N504.mat',
#  'N600.mat',
#  'N602.mat',
#  'N604.mat',
#  'N700.mat',
#  'N702.mat',
# ...
