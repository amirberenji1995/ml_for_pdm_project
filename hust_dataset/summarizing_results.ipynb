# %%
from experiments.result import Result
import os
import pandas as pd

# %%
def mean_accuracy_extractor(results_dict: str):
    files = [f for f in os.listdir(results_dict) if f.endswith(".json")]

    data_rows = {}

    for file in files:
        file_key = os.path.splitext(file)[0]

        result = Result({})
        result.load_json(results_dict + file)
        temp_df = result.tabulate()

        data_rows[file_key] = temp_df.mean()

    final_df = pd.DataFrame.from_dict(data_rows, orient="index")
    final_df.drop("seed", axis=1, inplace=True)
    return final_df

# %%
mean_df = mean_accuracy_extractor("experiments/results/")
mean_df
# Out:
# Successfully loaded results from experiments/results/with_additional_features_RF_{'n_estimators': 20}_hardcore.json
# Successfully loaded results from experiments/results/with_additional_features_SVM_{'probability': True, 'kernel': 'linear'}.json
# Successfully loaded results from experiments/results/with_additional_features_SVM_{'probability': True, 'kernel': 'rbf'}.json
# Successfully loaded results from experiments/results/with_additional_features_k-means_{'n_clusters': 3}_.json
# Successfully loaded results from experiments/results/with_additional_features_RF_{'n_estimators': 100}.json
# Successfully loaded results from experiments/results/with_additional_features_RF_{'n_estimators': 20}.json
# Successfully loaded results from experiments/results/with_additional_features_SVM_{'probability': True, 'kernel': 'poly', 'degree': 3}.json
# Successfully loaded results from experiments/results/with_additional_features_RF_{'n_estimators': 190}.json
# Successfully loaded results from experiments/results/with_additional_features_SVM_{'probability': True, 'kernel': 'sigmoid'}.json
# Successfully loaded results from experiments/results/original_None_None.json
# Successfully loaded results from experiments/results/with_additional_features_ANN_{'loss': 'categorical_crossentropy', 'lr': 0.01, 'epochs': 1000}.json
# Successfully loaded results from experiments/results/with_additional_features_RF_{'n_estimators': 50}.json
#                                                     power_classification_accuracy  \
# with_additional_features_RF_{'n_estimators': 20...                       0.794168
# with_additional_features_SVM_{'probability': Tr...                       0.347433
# with_additional_features_SVM_{'probability': Tr...                       0.447146
# with_additional_features_k-means_{'n_clusters':...                    -405.039520
# with_additional_features_RF_{'n_estimators': 100}                        0.804600
# with_additional_features_RF_{'n_estimators': 20}                         0.794825
# with_additional_features_SVM_{'probability': Tr...                       0.431540
# with_additional_features_RF_{'n_estimators': 190}                        0.807392
# with_additional_features_SVM_{'probability': Tr...                       0.338563
# original_None_None                                                            NaN
# with_additional_features_ANN_{'loss': 'categori...                       0.627351
# with_additional_features_RF_{'n_estimators': 50}                         0.802218
#
#                                                     fault_classification_accuracy
# with_additional_features_RF_{'n_estimators': 20...                       0.949076
# with_additional_features_SVM_{'probability': Tr...                       0.917536
# with_additional_features_SVM_{'probability': Tr...                       0.936591
# with_additional_features_k-means_{'n_clusters':...                       0.921889
# with_additional_features_RF_{'n_estimators': 100}                        0.946037
# with_additional_features_RF_{'n_estimators': 20}                         0.948912
# with_additional_features_SVM_{'probability': Tr...                       0.937248
# with_additional_features_RF_{'n_estimators': 190}                        0.943409
# with_additional_features_SVM_{'probability': Tr...                       0.936099
# original_None_None                                                       0.892156
# with_additional_features_ANN_{'loss': 'categori...                       0.936674
# with_additional_features_RF_{'n_estimators': 50}                         0.948830
