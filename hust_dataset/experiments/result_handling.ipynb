# %%
from result import Result

# %%
result = Result({})
result.load_json("results.json")
# Out:
# Successfully loaded results from results.json

# %%
result.repetitions
# Out:
# [{'seed': 794,
#   'power_classifier_evaluation': {'training_accuracy': 1.0,
#    'test_accuracy': 0.8045174537987679},
#   'fault_classifier_evaluation': {'training_accuracy': 0.5310146808624268,
#    'test_accuracy': 0.5203285217285156},
#   'fault_classifier_confusion_matrix': array([[  3,   3, 136,   0,   0,  17, 105],
#          [  0, 199,  66,  52,  24,  64,   0],
#          [  0,  25, 156,  72,   0,   7,  25],
#          [  0,  44,   0, 217,  17,  56,  48],
#          [  0,   0,   0,   0, 376,   0,   0],
#          [  0,   6,   0, 132,  75, 118,  76],
#          [  0,   7,  69,   0,   0,  42, 198]])},
#  {'seed': 391,
#   'power_classifier_evaluation': {'training_accuracy': 0.9998630699712447,
#    'test_accuracy': 0.811088295687885},
#   'fault_classifier_evaluation': {'training_accuracy': 0.6096124649047852,
#    'test_accuracy': 0.6032854318618774},
#   'fault_classifier_confusion_matrix': array([[ 36,  10,  78,   1,   0,  33, 107],
# ...

# %%
result.tabulate()
# Out:
#    seed  power_classification_accuracy  fault_classification_accuracy
# 0   794                       0.804517                       0.520329
# 1   391                       0.811088                       0.603285
# 2   183                       0.811910                       0.581109
# 3   525                       0.825462                       0.572485
# 4   654                       0.794661                       0.560575

# %%
result.confusion_matrix_visualizer()
